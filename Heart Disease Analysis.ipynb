# %%
# Heart Disease Analysis on Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

# %%
# Import the dataset
heart_disease_dataset=pd.read_csv('D:\iNeuron Data Analytics\Heart Disease\heart.csv')

# %%
heart_disease_dataset
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart_disease_dataset_copy=heart_disease_dataset.copy()

# %%
heart_disease_dataset_copy
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart_disease_dataset_copy.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart_disease_dataset_copy.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
heart_disease_dataset_copy.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_disease_dataset_copy.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_disease_dataset_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
heart_disease_dataset_copy.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart_disease_dataset_copy.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
check_duplicates=heart_disease_dataset_copy.duplicated().any()

# %%
check_duplicates # There are duplicates in the dataset
# Out:
# True

# %%
heart_disease_dataset_copy.shape
# Out:
# (1025, 14)

# %%
heart_disease_dataset_copy=heart_disease_dataset_copy.drop_duplicates()

# %%
heart_disease_dataset_copy.duplicated().any()
# Out:
# False

# %%
heart_disease_dataset_copy.shape # The shape of the dataset has got changed. That means the duplicates has been removed
# Out:
# (302, 14)

# %%
heart_disease_dataset_copy.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
plt.figure(figsize=(15,20))
sns.heatmap(heart_disease_dataset_copy.corr(),annot=True)
plt.show()

# %%
categorical_column=[]
numerical_column=[]
for i in heart_disease_dataset_copy:
    if heart_disease_dataset_copy[i].nunique()<=10:
        categorical_column.append(i)
    else:
        numerical_column.append(i)

# %%
print('The categorical columns are: ',categorical_column)
print('The numerical columns are: ',numerical_column)
# Out:
# The categorical columns are:  ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']
# The numerical columns are:  ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
numerical_column
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %% [markdown]
# # No of People suffering from heart disease

# %%
heart_disease_dataset_copy['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
target_counts=heart_disease_dataset_copy['target'].value_counts()
plt.bar(target_counts.index,target_counts.values)
plt.xlabel('Target')
plt.xticks([0,1],['Healthy Person','Diseased Person'])
plt.ylabel('Target Counts')
plt.title('Distribution of Target Variable')
plt.show()

# %% [markdown]
# # Total Number of Male and Female

# %%
heart_disease_dataset_copy['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
sex_counts=heart_disease_dataset_copy['sex'].value_counts()
plt.bar(sex_counts.index,sex_counts.values)
plt.xlabel('Sex')
plt.xticks([0,1],['Female','Male'])
plt.ylabel('Sex Counts')
plt.title('Distribution of Sex Counts')
plt.show()

# %% [markdown]
# # Age Distribution In The Dataset

# %%
plt.hist(heart_disease_dataset_copy['age'],bins=20)
plt.show()

# %% [markdown]
# # Types of Chest Pain

# %%
cp_counts=heart_disease_dataset_copy['cp'].value_counts()
plt.bar(cp_counts.index,cp_counts.values)
plt.xlabel('Chest Pain Type')
plt.xticks([0,1,2,3],['Typical Angina','Atypical Angina','Non-Anginal Pain','Asymptomatic'])
plt.ylabel('Chest Pain Counts')
plt.title('Distribution of Chest Pain')
plt.show()

# %% [markdown]
# # Chest Pain Distribution

# %%
sns.countplot(x='cp',hue='target',data=heart_disease_dataset_copy)
plt.xticks([0,1,2,3],['Typical Angina','Atypical Angina','Non-Anginal Pain','Asymptomatic'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# # Fasting Blood Sugar Distribution

# %%
sns.countplot(x='fbs',hue='target',data=heart_disease_dataset_copy)
plt.xticks([0,1],['False','True'])
plt.legend(labels=['Disease','No-Disease'])
plt.show()

# %% [markdown]
# # Resting Blood Sugar Distribution

# %%
heart_disease_dataset_copy['trestbps'].hist(grid=False)
plt.show()

# %% [markdown]
# # Resting Blood Pressure As Per Sex Column

# %%
g=sns.FacetGrid(heart_disease_dataset_copy,hue='sex',aspect=6)
g.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=['Male','Female'])
plt.show()

# %% [markdown]
# # Distribution of Serum Cholestrol

# %%
heart_disease_dataset_copy['chol'].hist(grid=False)
plt.show()

# %%
print('Min Age: ',heart_disease_dataset_copy['age'].min())
print('Median Age: ',heart_disease_dataset_copy['age'].median())
print('Max Age: ',heart_disease_dataset_copy['age'].max())
# Out:
# Min Age:  29
# Median Age:  55.5
# Max Age:  77

# %%
young_age_people=heart_disease_dataset_copy[(heart_disease_dataset_copy['age']>=29) & (heart_disease_dataset_copy['age']<40)]
middle_age_people=heart_disease_dataset_copy[(heart_disease_dataset_copy['age']>=40) & (heart_disease_dataset_copy['age']<55)]
elderly_age_people=heart_disease_dataset_copy[(heart_disease_dataset_copy['age']>55)]
print('Young Ages =',len(young_age_people))
print('Middle Ages =',len(middle_age_people))
print('Elderly Ages =',len(elderly_age_people))
# Out:
# Young Ages = 15
# Middle Ages = 128
# Elderly Ages = 151

# %%
plt.figure()
sns.barplot(x=['young_age_people','middle_age_people','elderly_age_people'],y=[len(young_age_people),len(middle_age_people),len(elderly_age_people)])
plt.xlabel('Age Category')
plt.ylabel('Ages')
plt.title('Age Distribution')
plt.show()
